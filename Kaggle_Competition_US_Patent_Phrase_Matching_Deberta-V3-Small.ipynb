# %%
# This notebook is by Anastasia Ruzmaikina, for Kaggle Competition US Patent Phrase to Phrase Matching

# %% [markdown]
# Can you extract meaning from a large, text-based dataset derived from inventions? Here's your chance to do so.
#
# The U.S. Patent and Trademark Office (USPTO) offers one of the largest repositories of scientific, technical, and commercial information in the world through its Open Data Portal. Patents are a form of intellectual property granted in exchange for the public disclosure of new and useful inventions. Because patents undergo an intensive vetting process prior to grant, and because the history of U.S. innovation spans over two centuries and 11 million patents, the U.S. patent archives stand as a rare combination of data volume, quality, and diversity.
#
# In this competition, you will train your models on a novel semantic similarity dataset to extract relevant information by matching key phrases in patent documents. Determining the semantic similarity between phrases is critically important during the patent search and examination process to determine if an invention has been described before. For example, if one invention claims "television set" and a prior publication describes "TV set", a model would ideally recognize these are the same and assist a patent attorney or examiner in retrieving relevant documents. This extends beyond paraphrase identification; if one invention claims a "strong material" and another uses "steel", that may also be a match. What counts as a "strong material" varies per domain (it may be steel in one domain and ripstop fabric in another, but you wouldn't want your parachute made of steel). We have included the Cooperative Patent Classification as the technical domain context as an additional feature to help you disambiguate these situations.
#
# Can you build a model to match phrases in order to extract contextual information, thereby helping the patent community connect the dots between millions of patent documents?

# %% [markdown]
# In this notebook, I use Deberta-V3-Small to classify key phrases in patents by similarity score. The best accuracy score of this notebook on the competition test dataset is 57%.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import keras_core as keras
import keras
import keras_nlp
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import requests
from keras.activations import softmax
import torch
torch.cuda.empty_cache()

print("TensorFlow version:", tf.__version__)
print("KerasNLP version:", keras_nlp.__version__)
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Using TensorFlow backend
# TensorFlow version: 2.16.1
# KerasNLP version: 0.14.4
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/config.json
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/tokenizer.json
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/tf_model.h5
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/vocab.txt
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/flax_model.msgpack
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/whole-word-masking/._bert_config.json
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/whole-word-masking/bert_config.json
# /kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased/whole-word-masking/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/384-8bits.tflite
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/tokenizer.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/tf_model.h5
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/384-fp16.tflite
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/vocab.txt
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/384.tflite
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/saved_model.pb
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/._variables
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/._assets
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/._saved_model.pb
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/._.
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/variables/variables.index
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/variables/._variables.index
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/variables/._variables.data-00000-of-00001
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/variables/variables.data-00000-of-00001
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/PaxHeader/assets
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/PaxHeader/variables
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad/saved_model/PaxHeader/currentdir
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/config.json
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/tokenizer.json
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/tf_model.h5
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/vocab.txt
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/flax_model.msgpack
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/whole-word-masking/._bert_config.json
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/whole-word-masking/bert_config.json
# /kaggle/input/huggingface-bert-variants/bert-large-cased/bert-large-cased/whole-word-masking/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/bert-base-cased/bert-base-cased/config.json
# /kaggle/input/huggingface-bert-variants/bert-base-cased/bert-base-cased/tokenizer.json
# /kaggle/input/huggingface-bert-variants/bert-base-cased/bert-base-cased/tf_model.h5
# /kaggle/input/huggingface-bert-variants/bert-base-cased/bert-base-cased/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/bert-base-cased/bert-base-cased/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/bert-base-cased/bert-base-cased/vocab.txt
# /kaggle/input/huggingface-bert-variants/bert-base-cased/bert-base-cased/flax_model.msgpack
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased/rust_model.ot
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased/config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased/tokenizer.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased/tf_model.h5
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased/vocab.txt
# /kaggle/input/huggingface-bert-variants/distilbert-base-multilingual-cased/distilbert-base-multilingual-cased/config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-multilingual-cased/distilbert-base-multilingual-cased/tokenizer.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-multilingual-cased/distilbert-base-multilingual-cased/tf_model.h5
# /kaggle/input/huggingface-bert-variants/distilbert-base-multilingual-cased/distilbert-base-multilingual-cased/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-multilingual-cased/distilbert-base-multilingual-cased/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-multilingual-cased/distilbert-base-multilingual-cased/vocab.txt
# /kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased/rust_model.ot
# /kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased/config.json
# /kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased/tokenizer.json
# /kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased/tf_model.h5
# /kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased/vocab.txt
# /kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased/flax_model.msgpack
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/rust_model.ot
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tokenizer.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tf_model.h5
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/vocab.txt
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/saved_model/saved_model.pb
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/saved_model/variables/variables.index
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/saved_model/variables/variables.data-00000-of-00001
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard10of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard40of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard2of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard4of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard57of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard48of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard23of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard22of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard45of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard19of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard39of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard38of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard56of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard41of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard55of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard32of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard15of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard16of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard17of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard36of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard18of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard27of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard58of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard6of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard61of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard53of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard14of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard46of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard33of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard62of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard47of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard54of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard63of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard12of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard8of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard43of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard59of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard13of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard30of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard25of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard1of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard51of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard42of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard7of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard9of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard49of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/model.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard21of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard34of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard3of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard24of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard28of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard31of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard35of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard5of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard20of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard26of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard50of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard29of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard44of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard11of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard37of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard52of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased-distilled-squad/distilbert-base-cased-distilled-squad/tfjs/group1-shard60of63.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased/distilbert-base-cased/config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased/distilbert-base-cased/tokenizer.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased/distilbert-base-cased/tf_model.h5
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased/distilbert-base-cased/tokenizer_config.json
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased/distilbert-base-cased/pytorch_model.bin
# /kaggle/input/huggingface-bert-variants/distilbert-base-cased/distilbert-base-cased/vocab.txt
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/384-8bits.tflite
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/config.json
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/coreml_model.mlmodel
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/README.md
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/tokenizer.json
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/tf_model.h5
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/384-fp16.tflite
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/tokenizer_config.json
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/coreml_model_fp16.mlmodel
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/pytorch_model.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/model.safetensors
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.gitattributes
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/vocab.txt
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/384.tflite
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/saved_model.pb
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/._variables
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/._assets
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/._saved_model.pb
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/._.
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/variables/variables.index
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/variables/._variables.index
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/variables/._variables.data-00000-of-00001
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/saved_model/variables/variables.data-00000-of-00001
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/config
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/packed-refs
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/index
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/description
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/info/exclude
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/refs/heads/main
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/refs/remotes/origin/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/pre-merge-commit.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/post-merge
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/pre-push
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/update.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/pre-push.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/pre-rebase.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/pre-applypatch.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/post-commit
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/post-checkout
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/push-to-checkout.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/pre-commit.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/commit-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/post-update.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/pre-receive.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/fsmonitor-watchman.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/hooks/applypatch-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/8f/ad/8fade195786e956affe2ef5e3abf6ed4c2a061fae90f0f90b6f334eb4a4f98ee
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/22/cb/22cbcd1c2d2e3190cdb7658f0fd330e4c2bc18056a1e6612a4430197b7368372
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/da/82/da82f87bde746039d095afc2930b34b10eafce4ed7e24f1114815a0eac00cb1c
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/b4/cb/b4cb8385132328f31bc7a63ef38eb3d8ee6b630d3c4fd72d62e8cec9dfa16245
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/6e/2a/6e2a8df35c8d00f8431e9bd753f8dc2329277ada99839059556890a3800c6a81
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/a8/f8/a8f85421e410ee12fa02f5a2edc45dd7c3db75bfc6c3a05d6bb4c0385527d7c0
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/99/aa/99aa0f0cc06c676f7f95d2c95abefedcd0037371db6b014268c29ea3d466aa68
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/f5/24/f524a67ca1e31c075e12d856ec43c478133c12048939fc0e5f3fa7662e8799f0
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/lfs/objects/c9/7c/c97c02b13632dd20672a07c7ac371a491933ee9d50d738f1e3b8b8106cadd3c5
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/logs/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/logs/refs/heads/main
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/d8/3c27c1bf738cef23c889593d0cc48d5f605efa
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/0d/f5ff8a1bbf0ce81d31bb86e7d17c31c228dbf4
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/19/1e4ac238eae75ddd6222265b86203f2e1d52d2
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/cf/4275adb8659c4084a2513251054fe6495f1d78
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/cf/c060aefb333330af23e9cf1f7a0eca63c1d6af
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/b8/2e3a1aaea09a786682861c68609122d8fe5d64
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/b2/7a2bfe9a9320b3da90d45d37eeb313b7f33b7f
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/c7/5e19754c4368830e2a63498a85d8aaa3991469
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/87/b901c50303b6ad3beb2403d54a71d09e2efb10
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/41/ae1b4f1efaea8750e9f2e13c85a3080ca22758
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/9e/61bcd8421baf729125d8e5b904c25da28c4bee
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/da/e237a2f2f668512b087d73c6d78c26d88ce196
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/89/2e3daf8152c510e30210df23dac64cfd3f417f
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/ac/dcfbdd228d7d9461ec884799be240bff5a8d68
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/ac/1824213ec0c6936f0242a7419654d8b2298f79
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/75/273531508d7784ce964a1d2781e7521b263adc
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/7d/0bdda8f48484a9a77e235b1f3d613f5d779390
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/12/d62ee05ab8bcec5fb6c2a57cb1eb0e8a626b34
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/dc/0ca20b562787549e317192d665e11980e61c44
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/dc/08351d4dc0732d9c8af04070ced089b201ce2f
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/dc/28e085fc6a907d7c5338c2bf90350a278c7c8f
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/94/9a6f013d67eb8a5b4b5b46026217b888021b88
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/f1/7d1f72fea14cea1081cade6f45c9b989a1fb79
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/e4/4e49f390b7116883337bcffa0348d36ce1fb65
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/e4/edf9fc038be5463e89641c65176a42619e5b15
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/6e/1de6cfeb5c3cc33aa99d89ecc3493b57101e1e
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/62/a5dfb9b35ec6a1bb5f816be8e89b63ee35408d
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/4b/49e24dd70eee25b65366b268c9317120de9892
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/79/19fbb03d31f44ebbeaaba539271d3251c14227
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/88/e6b7a23c900d5310519900a5a93819c7c5e1a3
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/67/65229e62800a05df6e64ddc3fd69de4a056a2c
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/a3/083c47bf057a335c37ce3492c8bf91c695061f
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/a7/f779dafaca35559cb3d8ca38c538e9f6bf0cbd
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/bc/2a84b2473de1586525d6bd41faf23cdece1531
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/bb/133e834d7dab8aa8eb3f04e0435db7a3a1ddc8
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/ba/ae7f4595c254cc24aadae6fdc86e4d934e5931
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/3e/b6a0a66780bc7dc63b7223ca74c65258927ca1
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/fb/140275c155a9c7c5a3b3e0e77a9e839594a938
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/d4/59802a5b4ae7eb402ce274f4f2d60d17263fa3
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/00/c64006fbfecf019a4dae350f07da2a183faf4f
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/c4/37cc563d866d1ab0db9687cfc71224aec14b62
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/c4/59c948cb58c607af6ecc17b27bfdd20820a69c
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/3f/9c529a4cac0cdb173cd659832a735c534a0d1d
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/9b/02e565ef5779cf7d37ee705a8f29694f688432
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/86/d4425fe247cdfa1c324d3d06bb40b187532f4b
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/f3/d845bcd6288bf86beaf267450a0cababa007cb
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/43/74e9f73e807a160fd0f67554cbb61c2b885771
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/71/2f843fe03a214b38b75710507139a3c9f597ee
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/30/d7c692d7aa2413bf41ce05acff7bc97c4303a5
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/7a/b5694f9b27d5bc3e72f6fe16864b3dcd8d60a6
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/14/806d5d8dd6671881a759a55ab696beb13cf578
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/6f/fccf2eed8a3159b4ed71ab0e0c92daa5ab1e95
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/5a/80cffb8cf3f470c5cd77947fd43da45a1c3c0c
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/3a/08b1cef284256e4a9e00ed485c7f5a9e9b65e2
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/3a/b4b58da34f3a23bbdd2626fc58ee6c91f9890b
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/a6/61b1a138dac6dc5590367402d100765010ffd6
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/83/d7dd1778d8aad01864450116eeb90d23bc8768
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/57/099ca850bb18652436fed90fd8498e905095df
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/5f/d13b8fe336f632c44f0e02c27cad425c56b3b1
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/5f/04724d1e82df8ea59e5af623c188eaa7bfb460
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/96/d1679311ea4f5fb8781939f3d685ad61b4a15d
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/96/9ee37a613a29c9290181b5174a44e45dbd7fcc
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/11/6907ae60c77b3843df3aeccaea6245e43d91b6
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/b3/118df9bb044bb5151df1f5298bd71e05a47205
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/0b/298d17370f921d509f47b8caa2e059a711e93b
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/5c/96cf151f09e252c138a0172fbe0994a5fc1925
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/ee/787b17f5d95c47f5f6e86285120a731dcbd63c
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased-distilled-squad/.git/objects/ee/86d7058982f242f06251720074c2bc612a2c0a
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/config.json
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/LICENSE
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/README.md
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/tokenizer.json
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/tokenizer_config.json
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/pytorch_model.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/model.safetensors
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.gitattributes
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/vocab.txt
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/config
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/packed-refs
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/index
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/description
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/info/exclude
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/refs/heads/main
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/refs/remotes/origin/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/pre-merge-commit.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/post-merge
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/pre-push
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/update.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/pre-push.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/pre-rebase.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/pre-applypatch.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/post-commit
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/post-checkout
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/push-to-checkout.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/pre-commit.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/commit-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/post-update.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/pre-receive.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/fsmonitor-watchman.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/hooks/applypatch-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/lfs/objects/17/f4/17f4f5b2f7e83b0a6f6031af68d16164716743e8edb8c555ab3ba540ac6e818b
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/lfs/objects/76/4a/764a3ad5aa5f599cd1a93619eba403fb1cce7ad61b5abefd0e2bc129bc34ded5
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/logs/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/logs/refs/heads/main
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/b8/ec93de907f7808f0b3f886dfcb3f5c2a96a155
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/05/316e6dde9f01d09196508808381a44fbcc91a8
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/06/b1dc5ba050ddbf462d060df38f906eedb31b01
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/da/ddc42228f94f8b060447bc1022d7eb7102a1ca
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/ff/e2c373ee61c832747be8cf3a674ba0ca041a00
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/52/af56c8513fbec35caab4f83a1625e0db7da4a2
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/f0/679dd83f9ab75b453c5ab0eabcbec98e3d0d27
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/8b/2e71f2cd157819b5550b5dbc0ebeed819edc2d
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/dc/08351d4dc0732d9c8af04070ced089b201ce2f
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/94/2cf9ae8dbcdbf06ea4825cb402498d2a20a2d4
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/55/0edbb7b571f7603e4a8709652c99a44f71e01e
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/a0/70f5a65373f44a961682692d7748f4a65c3895
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/be/82b254d3d925696dcd031198700b92dd987283
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/e3/c6d456fb2616f01a9a6cd01a1be1a36353ed22
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/4b/758ccbe160bcc69d31cc922d61cce034bafa4c
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/db/aff87555277b21c4dd6c93f7df63d6c622d3ae
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/ec/250413ad76bc4e8e7604e9fa0cbf20056ae892
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/f4/9a4e16e68b128803cc2dcea614603632b04eac
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/a5/9e0c1dce94a0e1606b646d279ccaefbae06a73
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/d4/34c79eafbe19292f6bb34d4fc948b37f0407f3
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/d4/59802a5b4ae7eb402ce274f4f2d60d17263fa3
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/90/05cf2a19d9fab3222c352cbc16280f94b893ee
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/90/4dfa13b46903129dcd398f8da588fbac7bb0c5
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/3f/49963ab9783d3ef3a59eecef0011e72271fe9b
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/91/6397498f1a75007a9d6de0235755931e234723
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/91/687b66997b2dfd6b5597f34a480e82ad13dc5e
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/71/2f843fe03a214b38b75710507139a3c9f597ee
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/2b/0c9fdb619e3c739a070d0fa013e5b1d36a2e18
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/5a/8d7949bf2993a652d5a753c1fabc2166859c40
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/83/de39fc9993e180cfcbf853e28b018552def5b5
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/83/529d763ecb42e18739a31657ad5ef1e6402423
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/21/be190620aef1211cd0a3d691920556a87ca6ef
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/9a/0990c5c0e00e26cc5ca4ba5c1c3ad533de7018
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/37/5023ca166e264e6c0bfd8c7140302ff831575f
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/f7/ed4c596181ba52fedff23451ac3593264ce381
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/f7/7cc0874b18caf2e7154e97bd3a2a23b6a19a3e
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/e9/65bc01b60e3fdbc37bdec617290425e6bc62d3
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/5c/6220823d4bfa9afb59a4d0e97608ee6e1cc812
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/c9/6fb02062982b2a6438066847978a9d5906bc09
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/c9/829260d524035ecb38e7b36530d84330a1dc91
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/3b/6342dffe9fc9e4c6528656101ccf2fc54d8999
# /kaggle/input/huggingface-distilbert/distilbert-base-german-cased/.git/objects/5d/2232a6c0b41eb1eeafa7049ef45cc963c171d2
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/rust_model.ot
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/config.json
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/LICENSE
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/README.md
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/tokenizer.json
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/tf_model.h5
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/tokenizer_config.json
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/pytorch_model.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/model.safetensors
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.gitattributes
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/vocab.txt
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/flax_model.msgpack
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/config
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/packed-refs
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/index
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/description
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/info/exclude
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/refs/heads/main
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/refs/remotes/origin/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/pre-merge-commit.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/post-merge
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/pre-push
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/update.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/pre-push.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/pre-rebase.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/pre-applypatch.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/post-commit
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/post-checkout
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/push-to-checkout.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/pre-commit.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/commit-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/post-update.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/pre-receive.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/fsmonitor-watchman.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/hooks/applypatch-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/lfs/objects/10/1f/101fa75462994e55b265fd62b0f44b9bb9f4d3fcb0c9d8986d2542850d0f0688
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/lfs/objects/e7/5c/e75cd1b76b546a498fe49ae3f0ca6f2ca4f2216c34010bea7232e8a0b95e93e8
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/lfs/objects/e6/0d/e60d71610916da4787c5513c81bc026d415708528295502fb3e1a6fe1485ea7c
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/lfs/objects/7f/f3/7ff3dc0119b9399681cf5661a9e450bb2ed2ecdb88338fb2c9d942c579164cc6
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/lfs/objects/5e/3f/5e3f1108e3cb34ee048634875d8482665b65ac713291a7e32396fb18f6ff0063
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/logs/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/logs/refs/heads/main
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/objects/b8/e399a4a2d00e268d1a6770eb536b7321854ed8
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/objects/b2/2dbc4a377fdc2c7115227abd6cc7fe55d4f49e
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/objects/b2/7b1b1e267317b80af985eae9f46f21e9500ebd
# /kaggle/input/huggingface-distilbert/distilbert-base-uncased/.git/objects/61/576ce34e0f775ca10ffa2342664d942b874582
# ...
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard62of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard47of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard54of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard63of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard12of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard8of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard43of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard59of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard13of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard30of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard25of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard1of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard51of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard42of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard7of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard9of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard49of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/model.json
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard21of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard34of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard3of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard24of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard28of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard31of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard35of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard5of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard20of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard26of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard50of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard29of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard44of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard11of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard37of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard52of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/tfjs/group1-shard60of63.bin
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/config
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/packed-refs
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/index
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/description
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/info/exclude
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/refs/heads/main
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/refs/remotes/origin/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/pre-merge-commit.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/post-merge
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/pre-push
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/update.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/pre-push.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/pre-rebase.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/pre-applypatch.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/post-commit
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/post-checkout
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/push-to-checkout.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/pre-commit.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/commit-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/post-update.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/pre-receive.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/fsmonitor-watchman.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/hooks/applypatch-msg.sample
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/lfs/objects/2e/96/2e966858819faa94996263752a344fad68f858299ccdf27ccabe3d868c588186
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/lfs/objects/f1/98/f198de8ef6e40aeccd6eaa86e34dde73c3bb4bf0e54003cd182a18c29a1811db
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/lfs/objects/4e/10/4e10bdbc83fdbb975a430fc2148c85051e55bd288334deab18db58664ef0ea13
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/lfs/objects/fb/e3/fbe35d48b0d713cac84817ee8f7433c0ae31c3ec91275c33ab0811bb482ca993
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/lfs/objects/63/ee/63ee5a0142067161ced524179c161c5026f47b53a34a946a5ad1a907fab35011
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/lfs/objects/f7/e2/f7e26fe22fdeb23462ae6423fc04b7e4929212a49aa033c3a7b8f30c937c943f
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/lfs/objects/8a/9f/8a9f9b2f153ac9ff230aca4548fa3286be9d2f9ea4eb7e9169665b1a8e983f44
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/logs/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/logs/refs/heads/main
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/17/1802f0553effa2f16da2d0f7b9c37b61f3c69c
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/17/037db69931ac4c02262814b120bc61a1ee1b90
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/22/851d03ed73dec03560f25999f30f8106c93478
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/b8/93b1f7f075bad3c44334fbc44b18c8d5346a6a
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/35/06cd531024c4fad2649aec20f7aa2020bca693
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/b2/2da401a54a88870e0997f4414f44b3ecd84bb7
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/50/ba811384f02cb99cdabe5cdc02f7ddc4f69e10
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/d5/cd6a8fac060a86c60516e506365d0dae463e50
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/1b/9d42b637aed70c9f3cd27e13b66ee9f847ed03
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/2e/a941cc79a6f3d7985ca6991ef4f67dad62af04
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/60/33b4a1fd44106fb6025f35e20d4439ba21b608
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/41/b2befbb5d0e14dead1bcc87b900d49098d7079
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/c8/0e0386c1bc4f7b8c42a80c034490658ad95908
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/8b/a81cdae7cdc987f5bcc5259f541a4a46158a05
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/7d/db6c675ace9298219ce064b1022979102f6ba9
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/dc/08351d4dc0732d9c8af04070ced089b201ce2f
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/a0/cfe919c5c3be548d49c19ad2588219f4c88ffd
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/be/c8e80b3fa2d0797b23f512ee8ab9b8a1a2411e
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/ea/5da623343fae6159ebd6efbc321eb46ce52016
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/e3/c6d456fb2616f01a9a6cd01a1be1a36353ed22
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/e4/5a5efde2aa2215710f269f2edbb44ea16a4cf8
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/b9/94d5a9a3be7f328e9145d97e57d1c882b144bb
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/b9/836d5b67b6b0ad70464292c71139a1f4688500
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/62/6af3168b44d7bc30c62ce00f32b76b189137a5
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/1a/7d2ea53f4d346ca7301c13f80b86bb5874f890
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/85/c530a33c3333829630e076860bf4bd078dab68
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/c2/b6d7d6b34a01acb2ef98bd054673079c6f5640
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/1e/61b22fe2763bbecbe404fe0b1b58c8736bb0ff
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/ab/869c350bf337ba638b12da62f29e4e7d67f15c
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/a3/a00226833876338bb56308efb0838b133b1707
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/a8/440a9ab1b3d7a603df3349516078434abade1e
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/bc/c101c61cd458a722950b5209902c1b2b89cc76
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/d4/19f612764c2e7b2cd75f2955841709abb40821
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/d4/59802a5b4ae7eb402ce274f4f2d60d17263fa3
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/4c/13d0c3660bacdc1c8e3e8eb691952fd416d64d
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/15/c0f59d4d6dcb52ec5943042da649f8998b102e
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/91/1f6c8a2c819c88e0f9c851e321df054d2e8061
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/3c/9289f429a1cf2c44de02a4e1ef3354ca81697d
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/71/2f843fe03a214b38b75710507139a3c9f597ee
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/ed/c226ce6c305ea3ed15131ef03f38828d144b31
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/59/0e77373050709e58e4959805802ae2c90c3a4d
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/5e/c9e54c2bc06522afeea35cf786450919c6814f
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/7c/4e5a03f322988e4a28fefdcfbadbbb916a9260
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/2d/81d2eeffc5be1dad0839e48c04dd02952f8606
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/d7/492effd4bfb733d8baf246cb674397a5039753
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/5f/88965095b4f481ebbe669be77fcfdd6345ac95
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/a1/f770d95ad2b2f840a06aee7c95ac2a0210f86f
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/9a/0990c5c0e00e26cc5ca4ba5c1c3ad533de7018
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/de/2f0b349079c00b381d8aa3e3aef38e802d22c3
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/d3/929f6cf06a4bb70d8c1a6dc25cc1207e060ac1
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/d3/04730eb85a2e0aa1a856d3c653f370441d8415
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/51/fe07557da411d72700be1705604185f4c0920f
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/f7/f8117164054ac697bc21071ad4de51f6bacab3
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/8c/4722a1e2b27c832a1b61134197319ec142823d
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/c9/4a9d7d4356b7131238c15ea1f97dc5a02583cc
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/c0/0e3b1d0818d325b89ce54987217e743ae461c0
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/fd/3143464465385b28645923d5fadf8e8a17c8ae
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/5d/e40524ea40721c8a381197355f96d1365f32e9
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/2f/92ff7ae9e7042421c4b5653c13f69df137e7a5
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/93/8816aae55e9a2307bbed4b94fae75d5080119f
# /kaggle/input/huggingface-distilbert/distilbert-base-cased-distilled-squad/.git/objects/2a/39937a31a28dd1f8b47f2aa8616d3919063177
# /kaggle/input/debertav3small/spm.model
# /kaggle/input/debertav3small/config.json
# /kaggle/input/debertav3small/README.md
# /kaggle/input/debertav3small/tf_model.h5
# /kaggle/input/debertav3small/tokenizer_config.json
# /kaggle/input/debertav3small/pytorch_model.bin
# /kaggle/input/us-patent-phrase-to-phrase-matching/sample_submission.csv
# /kaggle/input/us-patent-phrase-to-phrase-matching/train.csv
# /kaggle/input/us-patent-phrase-to-phrase-matching/test.csv

# %%
df1 = pd.read_csv("/kaggle/input/us-patent-phrase-to-phrase-matching/train.csv")
df2 = pd.read_csv("/kaggle/input/us-patent-phrase-to-phrase-matching/train.csv")
df = df1 #pd.concat([df1, df2], axis=0)
df= df.sample(frac =0.2)
df_train = df.reset_index()
df_train.drop(columns=['index'], inplace=True)
print(df_train.head())
df_test = pd.read_csv("/kaggle/input/us-patent-phrase-to-phrase-matching/test.csv")
df_test.head()

from datasets import load_dataset
#ds = load_dataset('csv', data_files=['/kaggle/input/llm-detect-ai-generated-text/train_essays.csv', '/kaggle/input/generated2/generated.csv', '/kaggle/input/generated1/generated1.csv'])
#print(ds)
print(len(df_train))
print(len(df_test))

df_train['anchor'] = df_train['anchor'].str.lower()
df_train['anchor'] = df_train['anchor'].str.replace("#", "")
#df_train = df_train.sample(frac=0.8)
df_test['anchor'] = df_test['anchor'].str.lower()#replace("#", "" )
df_train['target'] = df_train['target'].str.lower()
df_train['target'] = df_train['target'].str.replace("#", "")
#df_train = df_train.sample(frac=0.8)
df_test['target'] = df_test['target'].str.lower() #replace("#", "" )
# Out:
#                  id                   anchor                   target context  \
# 0  c39320ae0d02d6da         composite slurry     automotive composite     C04
# 1  d37da07e6d7a914d               close gate               closed box     F03
# 2  95c59b9bfb137d58   block selection signal  output of the capacitor     B41
# 3  8da7c718467da78a  expandable intraluminal      expandable elongate     A61
# 4  f1a472b505a640b0           receiver shaft              drive shaft     F41
#
#    score
# 0   0.00
# 1   0.00
# 2   0.25
# 3   0.50
# 4   0.50
# 7295
# 36

# %%
from sklearn.model_selection import train_test_split
from datasets import Dataset,DatasetDict
df_train['score'] = df_train['score']*4
df_train['score']= df_train['score'].round().astype(int)
#df_train['score']= df_train['score'].astype(str)
df_train['input'] = 'TEXT1: '+ df_train.anchor + ';  TEXT2: '+ df_train.target + ';' # ' ANC: ' + df_train.context
df_train.insert(1, 'input', df_train.pop('input'))
df_train
# Out:
#                     id                                              input  \
# 0     c39320ae0d02d6da  TEXT1: composite slurry;  TEXT2: automotive co...
# 1     d37da07e6d7a914d             TEXT1: close gate;  TEXT2: closed box;
# 2     95c59b9bfb137d58  TEXT1: block selection signal;  TEXT2: output ...
# 3     8da7c718467da78a  TEXT1: expandable intraluminal;  TEXT2: expand...
# 4     f1a472b505a640b0        TEXT1: receiver shaft;  TEXT2: drive shaft;
# ...                ...                                                ...
# 7290  fccaa89d213e3d6c  TEXT1: multiplexed data;  TEXT2: multiplex dig...
# 7291  0117ce8d8f8abe79   TEXT1: compression loss;  TEXT2: discharge loss;
# 7292  dfe314b5d6848738    TEXT1: moisture proof film;  TEXT2: film video;
# 7293  2b558317abd901d4           TEXT1: metal phase;  TEXT2: novel phase;
# 7294  cb508d1d018d9a96  TEXT1: transmit over interface;  TEXT2: serial...
#
#                        anchor                       target context  score
# 0            composite slurry         automotive composite     C04      0
# 1                  close gate                   closed box     F03      0
# 2      block selection signal      output of the capacitor     B41      1
# 3     expandable intraluminal          expandable elongate     A61      2
# 4              receiver shaft                  drive shaft     F41      2
# ...                       ...                          ...     ...    ...
# 7290         multiplexed data       multiplex digital data     H04      3
# 7291         compression loss               discharge loss     F04      2
# 7292      moisture proof film                   film video     H05      0
# 7293              metal phase                  novel phase     B22      1
# 7294  transmit over interface  serial peripheral interface     G11      1
#
# [7295 rows x 6 columns]

# %%
df_train1 = df_train.drop(['id', 'target', 'anchor'], axis=1)#, 'language'  , 'context' , 'target', 'anchor'
ds = Dataset.from_pandas(df_train1)
print(ds)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
#from transformers import DebertaV3Model
from transformers import AutoModelForSequenceClassification,AutoTokenizer
from transformers import TextClassificationPipeline, AutoTokenizer, AutoModelForSequenceClassification
from transformers import TrainingArguments,Trainer
model_nm = '/kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased'#'/kaggle/input/huggingface-bert-variants/distilbert-base-uncased-distilled-squad/distilbert-base-uncased-distilled-squad'
#'/kaggle/input/huggingface-bert-variants/bert-base-uncased/bert-base-uncased'
#'/kaggle/input/huggingface-bert-variants/bert-large-uncased/bert-large-uncased'
# #'/kaggle/input/debertav3small' #'/kaggle/input/huggingface-deberta-variants/deberta-base-mnli/deberta-base-mnli'  #'/kaggle/input/debertav3small'   
tokz = AutoTokenizer.from_pretrained(model_nm)
def tok_func(x): return tokz(x["input"])
tok_ds = ds.map(tok_func, batched=True)
tok_ds = tok_ds.rename_columns({'score':'labels'})
dds = tok_ds.train_test_split(0.15, seed=420)
print(dds)
df_test['input'] = 'TEXT1: ' + df_test.anchor + '; TEXT2: ' +df_test.target + ';' #' ANC: ' + df_test.context
df_test.insert(1, 'input', df_test.pop('input'))
df_test1 = df_test.drop(['id', 'target', 'anchor'], axis=1)#, 'context' , 'target', 'anchor'
eval_ds = Dataset.from_pandas(df_test1).map(tok_func, batched=True)
bs = 1
epochs = 2
lr = 4.15e-6

args = TrainingArguments('outputs', learning_rate=lr, warmup_ratio=0.1, lr_scheduler_type='cosine', fp16=True,
    evaluation_strategy="epoch", per_device_train_batch_size=bs, per_device_eval_batch_size=bs*2,
    num_train_epochs=epochs, weight_decay=0.01, report_to='none')
model = AutoModelForSequenceClassification.from_pretrained(model_nm, num_labels=5)

trainer = Trainer(model, args, train_dataset=dds['train'], eval_dataset=dds['test'],
                  tokenizer=tokz)#, compute_metrics=compute_metrics
trainer.train();
# Out:
# Dataset({
#     features: ['input', 'context', 'score'],
#     num_rows: 7295
# })
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/7295 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'context', 'labels', 'input_ids', 'attention_mask'],
#         num_rows: 6200
#     })
#     test: Dataset({
#         features: ['input', 'context', 'labels', 'input_ids', 'attention_mask'],
#         num_rows: 1095
#     })
# })
# Map:   0%|          | 0/36 [00:00<?, ? examples/s]
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at /kaggle/input/huggingface-bert-variants/distilbert-base-uncased/distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:488: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
#     <div>
#
#       <progress value='12400' max='12400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12400/12400 07:52, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.562900</td>
#       <td>1.716851</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.572400</td>
#       <td>1.717243</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
preds = trainer.predict(eval_ds).predictions.astype(float)
print(preds)
preds = np.clip(preds, 0, 1)

# Make predictions
#predictions = classifier.predict(X_test)

# Evaluate the model (optional)
#classifier.evaluate(X_test)
submission = df_test.id.copy().to_frame()
submission["score"] = np.argmax(preds, axis=1) * 0.25  #classifier.predict(X_test)
#submission = df_test.id.copy().to_frame()
#submission["prediction"] = np.argmax(predictions, axis=1)

#submission["generated"] = submission["generated"].round(1)
submission.to_csv("/kaggle/working/submission.csv", index=False)
# Out:
# [[-1.04101562 -0.14489746  3.68164062 -0.73730469 -2.609375  ]
#  [-1.63671875 -1.12011719  1.21191406 -0.04940796  0.18212891]
#  [ 1.0546875  -0.92871094  1.93261719 -0.31152344 -2.37109375]
#  [-0.79248047  4.87890625 -0.30053711 -1.85449219 -3.08398438]
#  [ 1.29882812 -0.33544922  1.78027344 -0.52001953 -2.85742188]
#  [-1.41210938 -1.33300781  3.0703125  -0.2722168  -0.93896484]
#  [-0.97363281 -0.09460449  3.60351562 -0.73779297 -2.66601562]
#  [ 3.38085938 -0.16271973 -0.61376953 -0.671875   -2.13867188]
#  [ 2.23046875  0.34716797  0.60888672 -0.59716797 -2.9140625 ]
#  [-1.72558594 -1.12207031  1.48730469 -0.13476562  0.11553955]
#  [-0.04074097  4.21875     0.13342285 -1.74707031 -3.47460938]
#  [ 2.44726562  0.76611328  0.07653809 -0.77099609 -3.0625    ]
#  [ 1.88964844 -0.47998047  1.24316406 -0.34838867 -2.6875    ]
#  [-1.86816406 -1.21289062  1.82519531 -0.18115234 -0.06304932]
#  [-1.44140625 -0.99169922  0.73974609 -0.00794983  0.29858398]
#  [-0.33081055  4.7578125  -0.54199219 -1.93359375 -3.2265625 ]
#  [-0.61914062  4.90234375 -0.27954102 -1.90136719 -3.19335938]
#  [ 1.99707031 -0.05230713  1.12207031 -0.46923828 -2.96875   ]
#  [ 1.46582031  2.69335938 -0.06082153 -1.35839844 -3.48242188]
#  [-0.56103516  4.9140625  -0.33837891 -1.9140625  -3.24804688]
#  [ 1.37695312  0.68603516  1.30175781 -0.68994141 -3.22265625]
#  [-0.66503906  4.9140625  -0.20385742 -1.83398438 -3.2109375 ]
#  [ 3.0078125  -0.23217773 -0.1116333  -0.51171875 -2.5       ]
#  [-0.81298828  4.9140625  -0.26708984 -1.87695312 -3.03320312]
#  [-1.80761719 -0.87792969  4.203125   -0.69775391 -1.72949219]
#  [ 3.27734375 -0.80029297 -0.71484375 -0.43920898 -1.64453125]
#  [ 3.38867188 -0.65136719 -0.70605469 -0.44702148 -1.75488281]
#  [ 3.36328125 -0.73291016 -0.72314453 -0.44848633 -1.65429688]
#  [ 3.20898438 -0.73193359 -0.51025391 -0.45507812 -1.86328125]
#  [-1.81933594 -1.19140625  1.70800781 -0.20080566  0.0163269 ]
#  [-0.22741699  4.703125   -0.33007812 -1.87988281 -3.24414062]
#  [-0.40283203  4.77734375 -0.44604492 -1.859375   -3.29296875]
#  [-1.90917969 -1.17578125  1.95703125 -0.18286133 -0.07904053]
#  [-0.67285156  4.55859375  0.06378174 -1.77734375 -3.31640625]
#  [-0.22998047  4.015625    0.35180664 -1.63964844 -3.59960938]
#  [-0.78613281  4.83984375 -0.18493652 -1.82226562 -3.14257812]]

# %%
sub = pd.read_csv('submission.csv')
sub
# Out:
#                   id  score
# 0   4112d61851461f60   0.50
# 1   09e418c93a776564   0.50
# 2   36baf228038e314b   0.00
# 3   1f37ead645e7f0c8   0.25
# 4   71a5b6ad068d531f   0.00
# 5   474c874d0c07bd21   0.50
# 6   442c114ed5c4e3c9   0.50
# 7   b8ae62ea5e1d8bdb   0.00
# 8   faaddaf8fcba8a3f   0.00
# 9   ae0262c02566d2ce   0.50
# 10  a8808e31641e856d   0.25
# 11  16ae4b99d3601e60   0.00
# 12  25c555ca3d5a2092   0.00
# 13  5203a36c501f1b7c   0.50
# 14  b9fdc772bb8fd61c   0.50
# 15  7aa5908a77a7ec24   0.25
# 16  d19ef3979396d47e   0.25
# 17  fd83613b7843f5e1   0.00
# 18  2a619016908bfa45   0.00
# 19  733979d75f59770d   0.25
# 20  6546846df17f9800   0.00
# 21  3ff0e7a35015be69   0.25
# 22  12ca31f018a2e2b9   0.00
# 23  03ba802ed4029e4d   0.25
# 24  c404f8b378cbb008   0.50
# 25  78243984c02a72e4   0.00
# 26  de51114bc0faec3e   0.00
# 27  7e3aff857f056bf9   0.00
# 28  26c3c6dc6174b589   0.00
# 29  b892011ab2e2cabc   0.50
# 30  8247ff562ca185cc   0.25
# 31  c057aecbba832387   0.25
# 32  9f2279ce667b21dc   0.50
# 33  b9ea2b06a878df6f   0.25
# 34  79795133c30ef097   0.25
# 35  25522ee5411e63e9   0.25

# %%
import os
def remove_folder_contents(folder):
    for the_file in os.listdir(folder):
        file_path = os.path.join(folder, the_file)
        try:
            if os.path.isfile(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                remove_folder_contents(file_path)
                os.rmdir(file_path)
        except Exception as e:
            print(e)

folder_path = '/kaggle/working'
#remove_folder_contents(folder_path)
#os.rmdir(folder_path)
